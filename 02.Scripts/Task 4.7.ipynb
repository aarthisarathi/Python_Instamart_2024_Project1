# %% [markdown]
# # Deriving New Variables - Exercise 4.7

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#### importing data

path = r'E:\Aarthi Sarathi\Career Foundry\Exercise 4\Instacart Basket Analsis'
df_ords_prods_merge = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.csv'))

# %%
df_ords_prods_merge.dtypes
# Out:
# Unnamed: 0                  int64
# product_id                  int64
# product_name               object
# aisle_id                    int64
# department_id               int64
# prices                    float64
# order_id                    int64
# add_to_cart_order           int64
# reordered                   int64
# user_id                     int64
# order_number                int64
# order_date_of_the_week      int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# _merge                     object
# dtype: object

# %%
#optimizing data
df_ords_prods_merge['prices']=df_ords_prods_merge['prices'].astype('float32')

# %%
# Create a subset of first million rows
df = df_ords_prods_merge[:1000000]

# %% [markdown]
# ### If condition to split prices

# %%
#IF condition to split prices

def price_label(row):
    if row['prices'] <=5:
        return 'Low Range Products'
    elif (row['prices'] >5) and (row['prices'] <=15):
        return 'Mid Range Products'
    elif row['prices'] >15:
        return 'High Range Products'
    else:
        return np.nan

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12444\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid Range Products     652638
# Low Range Products     338018
# High Range Products      9344
# Name: count, dtype: int64

# %%
# Find most expensive product.

df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# ### Using Loc() method in If then condition to split prices

# %%
# Use loc() method on df to avaoid memory error
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12444\2443691603.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: count, dtype: int64

# %%
# Use loc() method on entire ords_prods_merge dataframe to apply price range function

df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
df_ords_prods_merge
# Out:
#           Unnamed: 0  product_id                product_name  aisle_id  \
# 0                  0           1  Chocolate Sandwich Cookies        61
# 1                  1           1  Chocolate Sandwich Cookies        61
# 2                  2           1  Chocolate Sandwich Cookies        61
# 3                  3           1  Chocolate Sandwich Cookies        61
# 4                  4           1  Chocolate Sandwich Cookies        61
# ...              ...         ...                         ...       ...
# 32404854    32404854       49688      Fresh Foaming Cleanser        73
# 32404855    32404855       49688      Fresh Foaming Cleanser        73
# 32404856    32404856       49688      Fresh Foaming Cleanser        73
# 32404857    32404857       49688      Fresh Foaming Cleanser        73
# 32404858    32404858       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merge.rename(columns={'order_date_of_the_week': 'order_day_of_the_week'}, inplace=True)

# %%
df_ords_prods_merge['order_day_of_the_week'].value_counts(dropna = False)
# Out:
# order_day_of_the_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# ### for Loop find busiest , least , regular days in order_day_of_the_week

# %%
#for loop to find busiest , least , regular days

result = []

for value in df_ords_prods_merge["order_day_of_the_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Create new column in ords_prods_merge to view results in context.

df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           1           1  Chocolate Sandwich Cookies        61
# 2           2           1  Chocolate Sandwich Cookies        61
# 3           3           1  Chocolate Sandwich Cookies        61
# 4           4           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  add_to_cart_order  reordered  user_id  \
# 0             19     5.8      1107                  7          0    38259
# 1             19     5.8      5319                  3          1   196224
# 2             19     5.8      7540                  4          1   138499
# 3             19     5.8      9228                  2          0    79603
# 4             19     5.8      9273                 30          0    50005
#
#    order_number  order_day_of_the_week  order_hour_of_day  \
# 0             2                      1                 11
# ...

# %% [markdown]
# ## Task 4.7

# %% [markdown]
# ### Step 2 and Step 3

# %% [markdown]
# #### Create new column busiest_days in df_ords_prods_merge to store Busiest days , Slowest days and Regular days

# %%
result_2 = []

for value in df_ords_prods_merge["order_day_of_the_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 4 or value == 3:
    result_2.append("Slowest days")
  else:
    result_2.append("Regularly busy")
#Output
result_2
# Out:
# ['Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
# ...

# %%
#create coulmn to view results in df

df_ords_prods_merge['busiest_days'] = result_2

# %%
#check output
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           1           1  Chocolate Sandwich Cookies        61
# 2           2           1  Chocolate Sandwich Cookies        61
# 3           3           1  Chocolate Sandwich Cookies        61
# 4           4           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  add_to_cart_order  reordered  user_id  \
# 0             19     5.8      1107                  7          0    38259
# 1             19     5.8      5319                  3          1   196224
# 2             19     5.8      7540                  4          1   138499
# 3             19     5.8      9228                  2          0    79603
# 4             19     5.8      9273                 30          0    50005
#
#    order_number  order_day_of_the_week  order_hour_of_day  \
# 0             2                      1                 11
# ...

# %%
#check frequency

df_ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %% [markdown]
# Orders on Tuesday and wednesday are more comapred to saturday and sunday orders.
# Monday , Thursday and Friday are slowest days with less orders.

# %% [markdown]
# ### Step 4 and Step 5

# %% [markdown]
# ####  To Find Most orders , Average orders and Fewest orders in df_ords_prods_merge['order_hour_of_day'] by creating new column as busiest_period_of_day

# %%
#check Frequency of all hours

df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
result_3 = []
for value in df_ords_prods_merge['order_hour_of_day']:
    if value == 10 or value == 11 or value == 14 or value == 15 or value ==  13 or value == 12 or value ==  16 or value ==  9:
        result_3.append("Most orders")
    if value == 17 or value == 18 or value == 8 or value == 19 or value ==  20 or value == 7 or value ==  21 or value ==  22:
        result_3.append("Average orders")
    if value == 23 or value == 6 or value == 0 or value == 1 or value ==  2 or value == 3 or value ==  4 or value ==  5:
        result_3.append("Fewest orders")

#output
result_3
# Out:
# ['Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Average orders',
#  'Fewest orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
#create coulmn busiest_period_of_day to view results in df_ords_prods_merge

df_ords_prods_merge['busiest_period_of_day'] = result_3
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           1           1  Chocolate Sandwich Cookies        61
# 2           2           1  Chocolate Sandwich Cookies        61
# 3           3           1  Chocolate Sandwich Cookies        61
# 4           4           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  add_to_cart_order  reordered  user_id  \
# 0             19     5.8      1107                  7          0    38259
# 1             19     5.8      5319                  3          1   196224
# 2             19     5.8      7540                  4          1   138499
# 3             19     5.8      9228                  2          0    79603
# 4             19     5.8      9273                 30          0    50005
#
#    order_number  order_day_of_the_week  order_hour_of_day  \
# 0             2                      1                 11
# ...

# %%
#check frequency

df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# ### Step 7 Export your DataFrame

# %%
df_ords_prods_merge = df_ords_prods_merge.drop(['Unnamed: 0'], axis=1)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  add_to_cart_order  reordered  user_id  order_number  \
# 0      1107                  7          0    38259             2
# 1      5319                  3          1   196224            65
# 2      7540                  4          1   138499             8
# 3      9228                  2          0    79603             2
# 4      9273                 30          0    50005             1
#
#    order_day_of_the_week  order_hour_of_day  days_since_prior_order _merge  \
# ...

# %%
# Export to pkl

df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_derived.pkl'))
df_ords_prods_merge.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_derived.csv'))
